# %% [markdown]
# # Optional Lab: Logistic Regression, Decision Boundary

# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_common import plot_data, sigmoid, draw_vthresh
plt.style.use('./deeplearning.mplstyle')

# %%
X = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y = np.array([0, 0, 0, 1, 1, 1]).reshape(-1,1)

# %%
fig,ax = plt.subplots(1,1,figsize=(4,4))
plot_data(X, y, ax)

ax.axis([0, 4, 0, 3.5])
ax.set_ylabel('$x_1$')
ax.set_xlabel('$x_0$')
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# ## Refresher on Logistic Regression and decision boundary
# - we interpret the output of the model ($f$) as the probability that $y=1$ given $x$ and parametrized by $w$ and $b$
# - therefore, to get a final prediction ($y=0$ or $y=1$) from the logistic regression model, we can use the following heuristic
#   - if $f >= 0.5$, predit $y=1$
#   - else predict $y=0$

# %%
# Plot sigmoid(z) over a range of values from -10 to 10
z = np.arange(-10,11)

fig,ax = plt.subplots(1,1,figsize=(5,3))
# Plot z vs sigmoid(z)
ax.plot(z, sigmoid(z), c='b')
ax.set_title("sigmoid function")
ax.set_ylabel('sigmoid(z)')
ax.set_xlabel('z')
draw_vthresh(ax,0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# For a logistic regression model, $z = w \cdot x + b$, Therefore,
# - if $w \cdot x + b >= 0$, the model predicts $y=1$
# - if $w \cdot x + b < 0$, the model predicts $y=0$

# %% [markdown]
# ## Plotting decision boundary
# understand how the logistic regression model is making predictions
# - our logistic regression model has the form $f(x) = g(-3+x_0+x_1)$
# - this model predicts $y=1$ if $-3+x_0+x_1 >= 0$

# %%
x0 = np.arange(0,6)

x1 = 3 - x0
fig,ax = plt.subplots(1,1,figsize=(5,4))
# Plot the decision boundary
ax.plot(x0,x1, c="b")
ax.axis([0, 4, 0, 3.5])

# Fill the region below the line
ax.fill_between(x0,x1, alpha=0.2)

# Plot the original data
plot_data(X,y,ax)
ax.set_ylabel(r'$x_1$')
ax.set_xlabel(r'$x_0$')
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …
