# %% [markdown]
# # Python, Numpy, and Vectorization

# %%
import numpy as np
import time

# %% [markdown]
# ## Useful References
# NumPy Documentation including a basic introduction: <a href="https://numpy.org/doc/stable/">NumPy.org</a> <br>
# A challenging feature topic:  <a href="https://numpy.org/doc/stable/user/basics.broadcasting.html">NumPy Broadcasting</a>

# %% [markdown]
# ## Numpy Arrays
# - indexable
# - n-dimentional array
# - contain elements of the same type ```dtype```
# - 1-D array, shape (n, )

# %% [markdown]
# ## Vector Creation

# %%
# NumPy routines which allocate memory and fill arrays with value
a = np.zeros(4);                print(f"np.zeros(4) :   a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
a = np.zeros((4,));             print(f"np.zeros(4,) :  a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
a = np.random.random_sample(4); print(f"np.random.random_sample(4): a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
# Out:
# np.zeros(4) :   a = [0. 0. 0. 0.], a shape = (4,), a data type = float64
# np.zeros(4,) :  a = [0. 0. 0. 0.], a shape = (4,), a data type = float64
# np.random.random_sample(4): a = [0.79214596 0.13873613 0.59441663 0.68272303], a shape = (4,), a data type = float64

# %% [markdown]
# some data creation rountines do not take a shape touple

# %%
a = np.arange(4.)
b = np.random.rand(4)
a, b
# Out:
# (array([0., 1., 2., 3.]),
#  array([0.54908773, 0.41315485, 0.82020921, 0.02063144]))

# %% [markdown]
# values can be specified manually as well

# %% [markdown]
# ## Operations on Vectors
# ### Single vector operations

# %%
a = np.arange(4)
print(f"a             : {a}")

b = -a 
print(f"b = -a        : {b}")

b = np.sum(a) 
print(f"b = np.sum(a) : {b}")

b = np.mean(a)
print(f"b = np.mean(a): {b}")

b = a**2
print(f"b = a**2      : {b}")
# Out:
# a             : [0 1 2 3]
# b = -a        : [ 0 -1 -2 -3]
# b = np.sum(a) : 6
# b = np.mean(a): 1.5
# b = a**2      : [0 1 4 9]

# %% [markdown]
# ### Vector Vector Operations

# %%
b = 5 * a
b
# Out:
# array([ 0,  5, 10, 15])

# %%
c = np.dot(a, b)
c
# Out:
# 70

# %% [markdown]
# ## Matrix

# %%
a = np.zeros((1, 5))
b = np.random.random_sample((1, 1))
a, b
# Out:
# (array([[0., 0., 0., 0., 0.]]), array([[0.46957528]]))

# %%
# reshape is a convenient way to create matrices
a = np.arange(6).reshape(-1, 2)

# -1 means: automatically calculate this array
# 2 means: inner has 2 dim

a
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])
