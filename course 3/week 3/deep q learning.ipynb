# %% [markdown]
# # Deep Q-Learning

# %% [markdown]
# ## 1 - Import packages
# - ```numpy``` for scientific computing
# - ```dequeue``` data structure for memory buffer
# - ```nametuple``` used to store the experience tuples
# - ```gym``` a collection of environments that can be used to test RL algorithms
# - ```PIL.Image``` and ```pyvirtualdisplay``` render Lunar Lander environment

# %%
import time
from collections import deque, namedtuple

import gymnasium as gym
import numpy as np
import PIL.Image
import tensorflow as tf
import utils

from pyvirtualdisplay import Display
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.losses import MSE
from tensorflow.keras.optimizers import Adam

# %%
# # Set up a virtual display to render the Lunar Lander environment.
# Display(visible=0, size=(840, 480)).start();

# Set the random seed for TensorFlow
tf.random.set_seed(utils.SEED)

# %% [markdown]
# ## 2 - Hyperparameters

# %%
MEMORY_SIZE = 100_000     # size of memory buffer
GAMMA = 0.995             # discount factor
ALPHA = 1e-3              # learning rate  
NUM_STEPS_FOR_UPDATE = 4  # perform a learning update every C time steps

# %% [markdown]
# ## 3 - Landing Environment
# ### 3.1 Action Space
# - Do nothing = 0
# - Fire right engine = 1
# - Fire main engine = 2
# - Fire left engine = 3
#
# ### 3.2 Observation Space
# State vector with 8 variables:
# - $(x, y)$ coordinates. Landing pad at $(0, 0)$
# - linear velocities $(\dot x, \dot y)$
#
# ### 3.3 Rewards
# The Lunar Lander environment has the following reward system:
#
# - Landing on the landing pad and coming to rest is about 100-140 points.
# - If the lander moves away from the landing pad, it loses reward.
# - If the lander crashes, it receives -100 points.
# - If the lander comes to rest, it receives +100 points.
# - Each leg with ground contact is +10 points.
# - Firing the main engine is -0.3 points each frame.
# - Firing the side engine is -0.03 points each frame
# ## 4 - Load Environment

# %%
env = gym.make('LunarLander-v3')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File D:\AI_learning\.venv\lib\site-packages\gymnasium\envs\box2d\bipedal_walker.py:15
#      14 try:
# ---> 15     import Box2D
#      16     from Box2D.b2 import (
#      17         circleShape,
#      18         contactListener,
#    (...)
#      22         revoluteJointDef,
#      23     )
#
# ModuleNotFoundError: No module named 'Box2D'
#
# The above exception was the direct cause of the following exception:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 env = gym.make('LunarLander-v3')
#
# File D:\AI_learning\.venv\lib\site-packages\gymnasium\envs\registration.py:696, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     693     env_creator = env_spec.entry_point
#     694 else:
#     695     # Assume it's a string
# ...
